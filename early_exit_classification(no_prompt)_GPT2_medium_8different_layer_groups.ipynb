# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os


# project_path = '/content/MyDrive/ColabNotebooks/25FALL_MLACC/adaptive-inference-llm'
# project_path = '/content/drive/MyDrive/ColabNotebooks/25FALL_MLACC/adaptive-inference-llm/'
project_path = '/content/drive/MyDrive/Colab Notebooks/25FALL_MLACC/Final_project/adaptive-inference-llm/'
if project_path not in sys.path:
    sys.path.append(project_path)

#Print
print(sys.path)
print("Folder includes:", os.listdir(project_path))
# Out:
# ['/content', '/env/python', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.12/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/Colab Notebooks/25FALL_MLACC/Final_project/adaptive-inference-llm/']
# Folder includes: ['early_exit_classification(no prompt)-GPT2-medium.ipynb', 'README.md', 'analysis-early_exit_classification.ipynb', 'early_exit_classification(with prompt).ipynb', 'early_exit_classification(no prompt) - gpt2-base.ipynb', 'test.ipynb', 'strategies', 'Modern BERT', 'models', '.git', 'evaluation', '.ipynb_checkpoints']

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from transformers import AutoModelForCausalLM, AutoTokenizer
import numpy as np


class GPT2EarlyExitClassifier(nn.Module):
    def __init__(self, model_name, exit_layers, threshold, verbalizers):
        super().__init__()

        self.model = AutoModelForCausalLM.from_pretrained(model_name)
        self.model.eval()

        self.tokenizer = AutoTokenizer.from_pretrained(model_name)

        # GPT-2 components
        self.wte = self.model.transformer.wte          # word embeddings
        self.wpe = self.model.transformer.wpe          # position embeddings
        self.h = self.model.transformer.h              # list of transformer blocks
        self.ln_f = self.model.transformer.ln_f        # final layer norm
        self.lm_head = self.model.lm_head              # language modeling head

        self.num_layers = len(self.h)

        self.exit_layers = sorted(exit_layers)
        self.threshold = threshold
        self.verbalizers = verbalizers

        # Precompute token IDs of verbalizers
        self.verbalizer_token_ids = {}
        for dataset, class_map in verbalizers.items():
            tok_ids_map = {}
            for cls, words in class_map.items():
                token_lists = []
                for w in words:
                    ids = self.tokenizer.encode(" " + w, add_special_tokens=False)
                    token_lists.append(ids)
                tok_ids_map[cls] = token_lists
            self.verbalizer_token_ids[dataset] = tok_ids_map

    @torch.no_grad()
    def classify(self, text, dataset_name):

        # Convert to input IDs
        inputs = self.tokenizer(text, return_tensors="pt")
        input_ids = inputs["input_ids"]
        seq_len = input_ids.shape[1]
        last_index = seq_len - 1

        # --- STEP 1: Compute embeddings ---
        position_ids = torch.arange(0, seq_len, dtype=torch.long).unsqueeze(0)
        hidden = self.wte(input_ids) + self.wpe(position_ids)

        verbalizer_map = self.verbalizer_token_ids[dataset_name]

        # --- STEP 2: Iterate through GPT-2 blocks, EXIT EARLY WHEN POSSIBLE ---
        for layer_idx, block in enumerate(self.h):

            # Pass through one transformer layer
            hidden = block(hidden)[0]

            # If this is an early-exit layer → run classification
            if (layer_idx + 1) in self.exit_layers:
                cls_vec = hidden[:, last_index, :]      # [1, hidden_dim]
                logits = self.lm_head(cls_vec)[0]       # per-token logits

                # Compute class scores using verbalizers
                class_scores = []
                for cls, tok_lists in verbalizer_map.items():
                    vals = []
                    for tok_list in tok_lists:
                        idx = torch.tensor(tok_list, dtype=torch.long)
                        vals.append(logits[idx].mean().item())
                    class_scores.append(np.mean(vals))

                class_scores = torch.tensor(class_scores)
                probs = torch.softmax(class_scores, dim=-1)
                pred = int(torch.argmax(probs))
                conf = float(probs[pred])

                # TRUE EARLY EXIT
                if conf > self.threshold:
                    return pred, layer_idx + 1, conf

        # --- STEP 3: FINAL EXIT (after all layers) ---
        hidden = self.ln_f(hidden)
        cls_vec = hidden[:, last_index, :]
        logits = self.lm_head(cls_vec)[0]

        class_scores = []
        for cls, tok_lists in verbalizer_map.items():
            vals = []
            for tok_list in tok_lists:
                idx = torch.tensor(tok_list, dtype=torch.long)
                vals.append(logits[idx].mean().item())
            class_scores.append(np.mean(vals))

        class_scores = torch.tensor(class_scores)
        probs = torch.softmax(class_scores, dim=-1)
        pred = int(torch.argmax(probs))
        conf = float(probs[pred])

        return pred, self.num_layers, conf   # <---- FIXED (1-based final layer)

# %%
# ---------------------------------------
# BASELINE classifier (FINAL LAYER ONLY)
# ---------------------------------------
class GPT2BaselineClassifier(torch.nn.Module):
    def __init__(self, model_name, verbalizers):
        super().__init__()
        self.model = AutoModelForCausalLM.from_pretrained(
            model_name, output_hidden_states=True
        )
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.verbalizers = verbalizers
        self.num_layers = len(self.model.transformer.h)

        # Precompute tokens
        self.verbalizer_token_ids = {}
        for dataset, class_map in verbalizers.items():
            ids = {}
            for cls, words in class_map.items():
                tok_list = self.tokenizer.encode(" " + words[0])
                ids[cls] = tok_list
            self.verbalizer_token_ids[dataset] = ids

    @torch.no_grad()
    def classify(self, text, dataset_name):
        inputs = self.tokenizer(text, return_tensors="pt")
        input_ids = inputs["input_ids"]

        outputs = self.model(input_ids, output_hidden_states=True)
        hidden = outputs.hidden_states[self.num_layers][:, -1, :]

        logits = self.model.lm_head(hidden)[0]

        class_verbalizers = self.verbalizer_token_ids[dataset_name]
        scores = []

        for cls, tok_list in class_verbalizers.items():
            idx = torch.tensor(tok_list, dtype=torch.long)
            scores.append(logits[idx].mean().item())

        scores = torch.tensor(scores)
        probs = torch.softmax(scores, dim=-1)

        pred = int(torch.argmax(probs))
        return pred, self.num_layers, float(probs[pred])

# %%
verbalizers = {
    "sst2": {
        0: ["negative"],
        1: ["positive"]
    },
}

model = GPT2EarlyExitClassifier(
    model_name="gpt2-medium",
    exit_layers=[2, 4, 6, 8, 10, 12],
    threshold=0.8,
    verbalizers=verbalizers
)

# Print total number of transformer blocks in the model
print("Number of layers in model:", model.num_layers)

pred, layer_used, conf = model.classify(
    "This movie was great!",
    dataset_name="sst2"
)

print(pred, layer_used, conf)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Number of layers in model: 24
# 0 2 0.9987282266125374

# %%
 import time
import numpy as np

from evaluation.dataset_loaders.sst2 import load_sst2
from evaluation.dataset_loaders.agnews import load_agnews
from evaluation.dataset_loaders.amazon import load_amazon_polarity
from evaluation.dataset_loaders.imdb import load_imdb
from evaluation.dataset_loaders.dbpedia import load_dbpedia
from evaluation.dataset_loaders.yanswers import load_yahoo


# ---------------------------------------
# Verbalyzers for GPT-2 classification
verbalizers = {
    "sst2": {
        0: ["negative"],
        1: ["positive"],
    },

    "agnews": {
        0: ["international", "world", "global"],
        1: ["sports", "sport"],
        2: ["business", "finance", "market"],
        3: ["technology", "tech", "computer"],
    },

    "dbpedia": {
    0: ["company", "corporation", "business"],
    1: ["school", "university", "college"],
    2: ["artist", "painter", "musician"],
    3: ["athlete", "player", "sportsman"],
    4: ["leader", "politician", "official"],
    5: ["vehicle", "transport", "machine"],
    6: ["building", "structure", "facility"],
    7: ["nature", "landform", "environment"],
    8: ["village", "town", "settlement"],
    9: ["animal", "creature", "mammal"],
    10: ["plant", "tree", "flora"],
    11: ["album", "music", "record"],
    12: ["film", "movie", "cinema"],
    13: ["book", "novel", "writing"],
    },

    "yahoo": {
    0: ["society", "culture", "people"],
    1: ["science", "math", "physics"],
    2: ["health", "medicine", "medical"],
    3: ["education", "reference", "learning"],
    4: ["computer", "internet", "technology"],
    5: ["sports", "sport", "athletics"],
    6: ["business", "finance", "money"],
    7: ["entertainment", "music", "movies"],
    8: ["family", "relationships", "love"],
    9: ["politics", "government", "law"],
    },

    # NEW: IMDB binary sentiment
    "imdb": {
        0: ["negative", "bad", "terrible"],
        1: ["positive", "good", "excellent"],
    },

    # NEW: Amazon Polarity binary sentiment
    "amazon_polarity": {
        0: ["negative", "bad", "poor"],
        1: ["positive", "good", "amazing"],
    }
}

# ---------------------------------------
# Load datasets once
# ---------------------------------------
'''dataset_loaders = [
    ("sst2", load_sst2, "classification"),
    ("agnews", load_agnews, "classification"),
    ("dbpedia", load_dbpedia, "classification"),
    ("yahoo", load_yahoo, "classification"),
    ("imdb", load_imdb, "classification"),
    ("amazon_polarity", load_amazon_polarity, "classification")
]'''

dataset_loaders = [
    ("sst2", load_sst2, "classification"),
    #("imdb", load_imdb, "classification"),
    ("amazon_polarity", load_amazon_polarity, "classification")
]

cached_datasets = {}
print("Loading datasets once...\n")

for name, loader, task in dataset_loaders:
    print(f"Loading {name}...")
    cached_datasets[name] = {
        "data": loader(number=500),
        "task": task
    }

print("\nAll datasets loaded.\n")


# ---------------------------------------
# Extract (text, label) from any format
# ---------------------------------------
def extract_text_label(sample):
    if isinstance(sample, dict):
        if "text" in sample:
            return sample["text"], sample["label"]
        elif "sentence" in sample:
            return sample["sentence"], sample["label"]
        elif "input_text" in sample:
            return sample["input_text"], sample["label"]
        else:
            raise ValueError("Unknown dict format:", sample)

    if isinstance(sample, (tuple, list)):
        return sample[0], sample[1]

    raise ValueError("Unknown sample format:", sample)


# ---------------------------------------
# Evaluation
# ---------------------------------------
def evaluate_dataset(model, dataset, dataset_name):
    correct = 0
    total = 0
    layers_used = []
    total_tokens = 0

    start = time.time()

    for sample in dataset:
        text, label = extract_text_label(sample)

        pred, layer, conf = model.classify(text, dataset_name)

        correct += (pred == label)
        total += 1
        layers_used.append(layer)

        total_tokens += len(model.tokenizer(text)["input_ids"])

    end = time.time()
    latency = (end - start) / total

    return {
        "metric": "accuracy",
        "score": correct / total,
        "avg_latency_sec": latency,
        "tokens_per_sec": total_tokens / (end - start),
        "avg_layers_used": float(np.mean(layers_used)),
        "num_samples": total
    }


# ---------------------------------------
# Run baseline + early exit
# ---------------------------------------
results_table = []

# -------------------------
# BASELINE FIRST
# -------------------------
print("\n==============================")
print("Running BASELINE")
print("==============================")

baseline_model = GPT2BaselineClassifier(
    model_name="gpt2-medium",
    verbalizers=verbalizers
)

for name, meta in cached_datasets.items():
    dataset = meta["data"]
    print(f"\nTesting BASELINE on {name}...")

    result = evaluate_dataset(baseline_model, dataset, name)
    print(name, result)

    results_table.append({
        "dataset": name,
        "threshold": None,
        "mode": "baseline",
        "metric": result["metric"],
        "score": float(result["score"]),
        "avg_latency_sec": float(result["avg_latency_sec"]),
        "tokens_per_sec": float(result["tokens_per_sec"]),
        "avg_layers_used": float(result["avg_layers_used"]),
        "num_samples": int(result["num_samples"]),
    })


# -------------------------
# EARLY EXIT NEXT
# -------------------------
# exit_layer_groups = [
#     [3, 6, 9, 12, 15, 18, 21],
#     [6, 12, 18],
#     [5, 10, 15, 20],
#     [12]
# ]
exit_layer_groups = [
    [3, 6, 9, 12, 15, 18, 21],
    [6, 12, 18],
    [5, 10, 15, 20],
    [12],

    [2, 4, 6, 8, 10, 12, 16, 20],  # NEW early-biased
    [12, 14, 16, 18, 20],          # NEW late-biased
    [6, 18, 24],                   # NEW small + fallback
    [4, 8, 12, 16, 20],            # NEW
]


thresholds = [0.5, 0.6, 0.7, 0.8, 0.9, 1.0]

for exit_layers in exit_layer_groups:

    print("\n=================================================")
    print(f"Testing EXIT LAYERS: {exit_layers}")
    print("=================================================")

    for th in thresholds:

        print(f"\n----------------------------")
        print(f"Threshold = {th}")
        print(f"Exit Layers = {exit_layers}")
        print("----------------------------")

        # Build model with these exit layers + threshold
        model = GPT2EarlyExitClassifier(
            model_name="gpt2-medium",
            exit_layers=exit_layers,
            threshold=th,
            verbalizers=verbalizers
        )

        # Evaluate across datasets
        for name, meta in cached_datasets.items():
            dataset = meta["data"]

            print(f"\nTesting {name} (exit_layers={exit_layers}, threshold={th})...")

            result = evaluate_dataset(model, dataset, name)
            print(name, result)

            # Save results with exit_layers column added
            results_table.append({
                "dataset": name,
                "threshold": th,
                "exit_layers": str(exit_layers),       # <<< NEW COLUMN
                "mode": "early_exit",
                "metric": result["metric"],
                "score": float(result["score"]),
                "tokens_per_sec": float(result["tokens_per_sec"]),
                "avg_latency_sec": float(result["avg_latency_sec"]),
                "avg_layers_used": float(result["avg_layers_used"]),
                "num_samples": int(result["num_samples"]),
            })
# Out:
# Loading datasets once...
#
# Loading sst2...
# README.md: 0.00B [00:00, ?B/s]
# sst2/train-00000-of-00001.parquet:   0%|          | 0.00/3.11M [00:00<?, ?B/s]
# sst2/validation-00000-of-00001.parquet:   0%|          | 0.00/72.8k [00:00<?, ?B/s]
# sst2/test-00000-of-00001.parquet:   0%|          | 0.00/148k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/67349 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/872 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1821 [00:00<?, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Loading amazon_polarity...
# README.md: 0.00B [00:00, ?B/s]
# amazon_polarity/train-00000-of-00004.par(…):   0%|          | 0.00/260M [00:00<?, ?B/s]
# amazon_polarity/train-00001-of-00004.par(…):   0%|          | 0.00/258M [00:00<?, ?B/s]
# amazon_polarity/train-00002-of-00004.par(…):   0%|          | 0.00/255M [00:00<?, ?B/s]
# amazon_polarity/train-00003-of-00004.par(…):   0%|          | 0.00/254M [00:00<?, ?B/s]
# amazon_polarity/test-00000-of-00001.parq(…):   0%|          | 0.00/117M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/3600000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/400000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# All datasets loaded.
#
#
# ==============================
# Running BASELINE
# ==============================
# The following generation flags are not valid and may be ignored: ['output_hidden_states']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Testing BASELINE on sst2...
# sst2 {'metric': 'accuracy', 'score': 0.724, 'avg_latency_sec': 0.13431521081924438, 'tokens_per_sec': 175.51251162256577, 'avg_layers_used': 24.0, 'num_samples': 500}
#
# Testing BASELINE on amazon_polarity...
# amazon_polarity {'metric': 'accuracy', 'score': 0.198, 'avg_latency_sec': 0.23477631616592406, 'tokens_per_sec': 398.4984581403838, 'avg_layers_used': 24.0, 'num_samples': 500}
#
# =================================================
# Testing EXIT LAYERS: [3, 6, 9, 12, 15, 18, 21]
# =================================================
#
# ----------------------------
# Threshold = 0.5
# Exit Layers = [3, 6, 9, 12, 15, 18, 21]
# ----------------------------
#
# Testing sst2 (exit_layers=[3, 6, 9, 12, 15, 18, 21], threshold=0.5)...
# sst2 {'metric': 'accuracy', 'score': 0.488, 'avg_latency_sec': 0.017835349559783935, 'tokens_per_sec': 1321.757104954975, 'avg_layers_used': 3.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[3, 6, 9, 12, 15, 18, 21], threshold=0.5)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.496, 'avg_latency_sec': 0.02990688133239746, 'tokens_per_sec': 3128.310135722868, 'avg_layers_used': 3.0, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.6
# Exit Layers = [3, 6, 9, 12, 15, 18, 21]
# ----------------------------
#
# Testing sst2 (exit_layers=[3, 6, 9, 12, 15, 18, 21], threshold=0.6)...
# sst2 {'metric': 'accuracy', 'score': 0.488, 'avg_latency_sec': 0.01760612630844116, 'tokens_per_sec': 1338.9657433445523, 'avg_layers_used': 3.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[3, 6, 9, 12, 15, 18, 21], threshold=0.6)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.498, 'avg_latency_sec': 0.030817816734313965, 'tokens_per_sec': 3035.841273461408, 'avg_layers_used': 3.138, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.7
# Exit Layers = [3, 6, 9, 12, 15, 18, 21]
# ----------------------------
#
# Testing sst2 (exit_layers=[3, 6, 9, 12, 15, 18, 21], threshold=0.7)...
# sst2 {'metric': 'accuracy', 'score': 0.488, 'avg_latency_sec': 0.017498151779174805, 'tokens_per_sec': 1347.2279985624702, 'avg_layers_used': 3.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[3, 6, 9, 12, 15, 18, 21], threshold=0.7)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.49, 'avg_latency_sec': 0.03232545566558838, 'tokens_per_sec': 2894.251544908488, 'avg_layers_used': 3.336, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.8
# Exit Layers = [3, 6, 9, 12, 15, 18, 21]
# ----------------------------
#
# Testing sst2 (exit_layers=[3, 6, 9, 12, 15, 18, 21], threshold=0.8)...
# sst2 {'metric': 'accuracy', 'score': 0.488, 'avg_latency_sec': 0.017621726989746095, 'tokens_per_sec': 1337.7803443281964, 'avg_layers_used': 3.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[3, 6, 9, 12, 15, 18, 21], threshold=0.8)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.472, 'avg_latency_sec': 0.03556224536895752, 'tokens_per_sec': 2630.823757874054, 'avg_layers_used': 3.84, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.9
# Exit Layers = [3, 6, 9, 12, 15, 18, 21]
# ----------------------------
#
# Testing sst2 (exit_layers=[3, 6, 9, 12, 15, 18, 21], threshold=0.9)...
# sst2 {'metric': 'accuracy', 'score': 0.488, 'avg_latency_sec': 0.01789139986038208, 'tokens_per_sec': 1317.6162952012055, 'avg_layers_used': 3.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[3, 6, 9, 12, 15, 18, 21], threshold=0.9)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.464, 'avg_latency_sec': 0.03962691640853882, 'tokens_per_sec': 2360.9709883921246, 'avg_layers_used': 4.554, 'num_samples': 500}
#
# ----------------------------
# Threshold = 1.0
# Exit Layers = [3, 6, 9, 12, 15, 18, 21]
# ----------------------------
#
# Testing sst2 (exit_layers=[3, 6, 9, 12, 15, 18, 21], threshold=1.0)...
# sst2 {'metric': 'accuracy', 'score': 0.724, 'avg_latency_sec': 0.13539749908447266, 'tokens_per_sec': 174.10956745436266, 'avg_layers_used': 24.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[3, 6, 9, 12, 15, 18, 21], threshold=1.0)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.18, 'avg_latency_sec': 0.2268670530319214, 'tokens_per_sec': 412.39130472962904, 'avg_layers_used': 24.0, 'num_samples': 500}
#
# =================================================
# Testing EXIT LAYERS: [6, 12, 18]
# =================================================
#
# ----------------------------
# Threshold = 0.5
# Exit Layers = [6, 12, 18]
# ----------------------------
#
# Testing sst2 (exit_layers=[6, 12, 18], threshold=0.5)...
# sst2 {'metric': 'accuracy', 'score': 0.55, 'avg_latency_sec': 0.032519344806671145, 'tokens_per_sec': 724.9223543754774, 'avg_layers_used': 6.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[6, 12, 18], threshold=0.5)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.47, 'avg_latency_sec': 0.054158229827880856, 'tokens_per_sec': 1727.4936846594642, 'avg_layers_used': 6.0, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.6
# Exit Layers = [6, 12, 18]
# ----------------------------
#
# Testing sst2 (exit_layers=[6, 12, 18], threshold=0.6)...
# sst2 {'metric': 'accuracy', 'score': 0.546, 'avg_latency_sec': 0.03439439821243286, 'tokens_per_sec': 685.402310411074, 'avg_layers_used': 6.708, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[6, 12, 18], threshold=0.6)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.474, 'avg_latency_sec': 0.05542322444915772, 'tokens_per_sec': 1688.0649029329768, 'avg_layers_used': 6.156, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.7
# Exit Layers = [6, 12, 18]
# ----------------------------
#
# Testing sst2 (exit_layers=[6, 12, 18], threshold=0.7)...
# sst2 {'metric': 'accuracy', 'score': 0.528, 'avg_latency_sec': 0.039048493862152096, 'tokens_per_sec': 603.7108648343846, 'avg_layers_used': 7.572, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[6, 12, 18], threshold=0.7)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.462, 'avg_latency_sec': 0.05743646955490112, 'tokens_per_sec': 1628.8953817151282, 'avg_layers_used': 6.564, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.8
# Exit Layers = [6, 12, 18]
# ----------------------------
# HTTP Error 504 thrown while requesting HEAD https://huggingface.co/gpt2-medium/resolve/main/config.json
# WARNING:huggingface_hub.utils._http:HTTP Error 504 thrown while requesting HEAD https://huggingface.co/gpt2-medium/resolve/main/config.json
# Retrying in 1s [Retry 1/5].
# WARNING:huggingface_hub.utils._http:Retrying in 1s [Retry 1/5].
# Testing sst2 (exit_layers=[6, 12, 18], threshold=0.8)...
# sst2 {'metric': 'accuracy', 'score': 0.526, 'avg_latency_sec': 0.04584515953063965, 'tokens_per_sec': 514.2091387913006, 'avg_layers_used': 9.06, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[6, 12, 18], threshold=0.8)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.45, 'avg_latency_sec': 0.05997298955917359, 'tokens_per_sec': 1560.0022724845003, 'avg_layers_used': 6.948, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.9
# Exit Layers = [6, 12, 18]
# ----------------------------
#
# Testing sst2 (exit_layers=[6, 12, 18], threshold=0.9)...
# sst2 {'metric': 'accuracy', 'score': 0.546, 'avg_latency_sec': 0.05600725984573364, 'tokens_per_sec': 420.9097189352275, 'avg_layers_used': 11.22, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[6, 12, 18], threshold=0.9)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.428, 'avg_latency_sec': 0.06562079524993897, 'tokens_per_sec': 1425.7370646553848, 'avg_layers_used': 7.692, 'num_samples': 500}
#
# ----------------------------
# Threshold = 1.0
# Exit Layers = [6, 12, 18]
# ----------------------------
#
# Testing sst2 (exit_layers=[6, 12, 18], threshold=1.0)...
# sst2 {'metric': 'accuracy', 'score': 0.724, 'avg_latency_sec': 0.11940951681137085, 'tokens_per_sec': 197.42145039611407, 'avg_layers_used': 24.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[6, 12, 18], threshold=1.0)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.18, 'avg_latency_sec': 0.2118294849395752, 'tokens_per_sec': 441.666560378446, 'avg_layers_used': 24.0, 'num_samples': 500}
#
# =================================================
# Testing EXIT LAYERS: [5, 10, 15, 20]
# =================================================
#
# ----------------------------
# Threshold = 0.5
# Exit Layers = [5, 10, 15, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[5, 10, 15, 20], threshold=0.5)...
# sst2 {'metric': 'accuracy', 'score': 0.614, 'avg_latency_sec': 0.026781660556793215, 'tokens_per_sec': 880.2292131964317, 'avg_layers_used': 5.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[5, 10, 15, 20], threshold=0.5)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.48, 'avg_latency_sec': 0.04633492469787598, 'tokens_per_sec': 2019.1680597311677, 'avg_layers_used': 5.0, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.6
# Exit Layers = [5, 10, 15, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[5, 10, 15, 20], threshold=0.6)...
# sst2 {'metric': 'accuracy', 'score': 0.61, 'avg_latency_sec': 0.03476703262329101, 'tokens_per_sec': 678.0561417314455, 'avg_layers_used': 6.6, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[5, 10, 15, 20], threshold=0.6)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.472, 'avg_latency_sec': 0.04815327739715576, 'tokens_per_sec': 1942.9207118833854, 'avg_layers_used': 5.26, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.7
# Exit Layers = [5, 10, 15, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[5, 10, 15, 20], threshold=0.7)...
# sst2 {'metric': 'accuracy', 'score': 0.57, 'avg_latency_sec': 0.04281258821487427, 'tokens_per_sec': 550.6324420678156, 'avg_layers_used': 8.2, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[5, 10, 15, 20], threshold=0.7)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.472, 'avg_latency_sec': 0.049788183212280276, 'tokens_per_sec': 1879.1205857241218, 'avg_layers_used': 5.638, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.8
# Exit Layers = [5, 10, 15, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[5, 10, 15, 20], threshold=0.8)...
# sst2 {'metric': 'accuracy', 'score': 0.552, 'avg_latency_sec': 0.05087877655029297, 'tokens_per_sec': 463.33661299220563, 'avg_layers_used': 9.81, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[5, 10, 15, 20], threshold=0.8)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.462, 'avg_latency_sec': 0.053925925254821774, 'tokens_per_sec': 1734.9354611515828, 'avg_layers_used': 6.19, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.9
# Exit Layers = [5, 10, 15, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[5, 10, 15, 20], threshold=0.9)...
# sst2 {'metric': 'accuracy', 'score': 0.546, 'avg_latency_sec': 0.05848099946975708, 'tokens_per_sec': 403.1052857123463, 'avg_layers_used': 11.278, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[5, 10, 15, 20], threshold=0.9)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.448, 'avg_latency_sec': 0.05797661685943604, 'tokens_per_sec': 1613.719548811046, 'avg_layers_used': 6.864, 'num_samples': 500}
#
# ----------------------------
# Threshold = 1.0
# Exit Layers = [5, 10, 15, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[5, 10, 15, 20], threshold=1.0)...
# sst2 {'metric': 'accuracy', 'score': 0.724, 'avg_latency_sec': 0.1229842848777771, 'tokens_per_sec': 191.6830270097359, 'avg_layers_used': 24.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[5, 10, 15, 20], threshold=1.0)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.18, 'avg_latency_sec': 0.21532512760162353, 'tokens_per_sec': 434.4964335657711, 'avg_layers_used': 24.0, 'num_samples': 500}
#
# =================================================
# Testing EXIT LAYERS: [12]
# =================================================
#
# ----------------------------
# Threshold = 0.5
# Exit Layers = [12]
# ----------------------------
#
# Testing sst2 (exit_layers=[12], threshold=0.5)...
# sst2 {'metric': 'accuracy', 'score': 0.522, 'avg_latency_sec': 0.05642416858673096, 'tokens_per_sec': 417.7996874471235, 'avg_layers_used': 12.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[12], threshold=0.5)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.414, 'avg_latency_sec': 0.10226453971862794, 'tokens_per_sec': 914.8625736488599, 'avg_layers_used': 12.0, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.6
# Exit Layers = [12]
# ----------------------------
#
# Testing sst2 (exit_layers=[12], threshold=0.6)...
# sst2 {'metric': 'accuracy', 'score': 0.52, 'avg_latency_sec': 0.057037678718566895, 'tokens_per_sec': 413.30573981311403, 'avg_layers_used': 12.024, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[12], threshold=0.6)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.4, 'avg_latency_sec': 0.10662992429733277, 'tokens_per_sec': 877.4084818734159, 'avg_layers_used': 12.456, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.7
# Exit Layers = [12]
# ----------------------------
#
# Testing sst2 (exit_layers=[12], threshold=0.7)...
# sst2 {'metric': 'accuracy', 'score': 0.52, 'avg_latency_sec': 0.05753724098205566, 'tokens_per_sec': 409.7172474320085, 'avg_layers_used': 12.192, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[12], threshold=0.7)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.388, 'avg_latency_sec': 0.10961892986297607, 'tokens_per_sec': 853.4839750483582, 'avg_layers_used': 13.008, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.8
# Exit Layers = [12]
# ----------------------------
#
# Testing sst2 (exit_layers=[12], threshold=0.8)...
# sst2 {'metric': 'accuracy', 'score': 0.528, 'avg_latency_sec': 0.058474193096160886, 'tokens_per_sec': 403.15220701263075, 'avg_layers_used': 12.36, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[12], threshold=0.8)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.37, 'avg_latency_sec': 0.11538869905471802, 'tokens_per_sec': 810.8073040639295, 'avg_layers_used': 13.656, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.9
# Exit Layers = [12]
# ----------------------------
#
# Testing sst2 (exit_layers=[12], threshold=0.9)...
# sst2 {'metric': 'accuracy', 'score': 0.546, 'avg_latency_sec': 0.060615949630737305, 'tokens_per_sec': 388.9075423813212, 'avg_layers_used': 12.936, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[12], threshold=0.9)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.338, 'avg_latency_sec': 0.11960613679885865, 'tokens_per_sec': 782.2173887058677, 'avg_layers_used': 14.328, 'num_samples': 500}
#
# ----------------------------
# Threshold = 1.0
# Exit Layers = [12]
# ----------------------------
#
# Testing sst2 (exit_layers=[12], threshold=1.0)...
# sst2 {'metric': 'accuracy', 'score': 0.724, 'avg_latency_sec': 0.1123624701499939, 'tokens_per_sec': 209.8031484047192, 'avg_layers_used': 24.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[12], threshold=1.0)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.18, 'avg_latency_sec': 0.20327464389801025, 'tokens_per_sec': 460.25415765549786, 'avg_layers_used': 24.0, 'num_samples': 500}
#
# =================================================
# Testing EXIT LAYERS: [2, 4, 6, 8, 10, 12, 16, 20]
# =================================================
#
# ----------------------------
# Threshold = 0.5
# Exit Layers = [2, 4, 6, 8, 10, 12, 16, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[2, 4, 6, 8, 10, 12, 16, 20], threshold=0.5)...
# sst2 {'metric': 'accuracy', 'score': 0.488, 'avg_latency_sec': 0.01385370111465454, 'tokens_per_sec': 1701.639136350593, 'avg_layers_used': 2.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[2, 4, 6, 8, 10, 12, 16, 20], threshold=0.5)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.508, 'avg_latency_sec': 0.021272563934326173, 'tokens_per_sec': 4398.059410649201, 'avg_layers_used': 2.0, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.6
# Exit Layers = [2, 4, 6, 8, 10, 12, 16, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[2, 4, 6, 8, 10, 12, 16, 20], threshold=0.6)...
# sst2 {'metric': 'accuracy', 'score': 0.488, 'avg_latency_sec': 0.013175363063812257, 'tokens_per_sec': 1789.248606343826, 'avg_layers_used': 2.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[2, 4, 6, 8, 10, 12, 16, 20], threshold=0.6)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.51, 'avg_latency_sec': 0.02297791576385498, 'tokens_per_sec': 4071.6486630684676, 'avg_layers_used': 2.156, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.7
# Exit Layers = [2, 4, 6, 8, 10, 12, 16, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[2, 4, 6, 8, 10, 12, 16, 20], threshold=0.7)...
# sst2 {'metric': 'accuracy', 'score': 0.488, 'avg_latency_sec': 0.013888404846191407, 'tokens_per_sec': 1697.3871557657435, 'avg_layers_used': 2.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[2, 4, 6, 8, 10, 12, 16, 20], threshold=0.7)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.506, 'avg_latency_sec': 0.024048621654510497, 'tokens_per_sec': 3890.3684936326695, 'avg_layers_used': 2.368, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.8
# Exit Layers = [2, 4, 6, 8, 10, 12, 16, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[2, 4, 6, 8, 10, 12, 16, 20], threshold=0.8)...
# sst2 {'metric': 'accuracy', 'score': 0.488, 'avg_latency_sec': 0.01333652114868164, 'tokens_per_sec': 1767.6273847719551, 'avg_layers_used': 2.004, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[2, 4, 6, 8, 10, 12, 16, 20], threshold=0.8)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.476, 'avg_latency_sec': 0.028069526195526124, 'tokens_per_sec': 3333.080841774657, 'avg_layers_used': 2.936, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.9
# Exit Layers = [2, 4, 6, 8, 10, 12, 16, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[2, 4, 6, 8, 10, 12, 16, 20], threshold=0.9)...
# sst2 {'metric': 'accuracy', 'score': 0.49, 'avg_latency_sec': 0.014588440418243408, 'tokens_per_sec': 1615.9369558462056, 'avg_layers_used': 2.136, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[2, 4, 6, 8, 10, 12, 16, 20], threshold=0.9)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.466, 'avg_latency_sec': 0.03346041631698608, 'tokens_per_sec': 2796.0799744295336, 'avg_layers_used': 3.704, 'num_samples': 500}
#
# ----------------------------
# Threshold = 1.0
# Exit Layers = [2, 4, 6, 8, 10, 12, 16, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[2, 4, 6, 8, 10, 12, 16, 20], threshold=1.0)...
# sst2 {'metric': 'accuracy', 'score': 0.724, 'avg_latency_sec': 0.14027877426147461, 'tokens_per_sec': 168.05108345228984, 'avg_layers_used': 24.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[2, 4, 6, 8, 10, 12, 16, 20], threshold=1.0)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.18, 'avg_latency_sec': 0.23022605562210083, 'tokens_per_sec': 406.3745076429081, 'avg_layers_used': 24.0, 'num_samples': 500}
#
# =================================================
# Testing EXIT LAYERS: [12, 14, 16, 18, 20]
# =================================================
#
# ----------------------------
# Threshold = 0.5
# Exit Layers = [12, 14, 16, 18, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[12, 14, 16, 18, 20], threshold=0.5)...
# sst2 {'metric': 'accuracy', 'score': 0.522, 'avg_latency_sec': 0.05742810487747192, 'tokens_per_sec': 410.4958721918, 'avg_layers_used': 12.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[12, 14, 16, 18, 20], threshold=0.5)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.414, 'avg_latency_sec': 0.10278295421600342, 'tokens_per_sec': 910.2482090890604, 'avg_layers_used': 12.0, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.6
# Exit Layers = [12, 14, 16, 18, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[12, 14, 16, 18, 20], threshold=0.6)...
# sst2 {'metric': 'accuracy', 'score': 0.52, 'avg_latency_sec': 0.057453160762786865, 'tokens_per_sec': 410.31685092718476, 'avg_layers_used': 12.004, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[12, 14, 16, 18, 20], threshold=0.6)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.408, 'avg_latency_sec': 0.10345173406600952, 'tokens_per_sec': 904.3637677479952, 'avg_layers_used': 12.088, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.7
# Exit Layers = [12, 14, 16, 18, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[12, 14, 16, 18, 20], threshold=0.7)...
# sst2 {'metric': 'accuracy', 'score': 0.514, 'avg_latency_sec': 0.056956323146820066, 'tokens_per_sec': 413.89609963465773, 'avg_layers_used': 12.032, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[12, 14, 16, 18, 20], threshold=0.7)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.404, 'avg_latency_sec': 0.10457028102874756, 'tokens_per_sec': 894.6901459916689, 'avg_layers_used': 12.216, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.8
# Exit Layers = [12, 14, 16, 18, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[12, 14, 16, 18, 20], threshold=0.8)...
# sst2 {'metric': 'accuracy', 'score': 0.516, 'avg_latency_sec': 0.057202425479888915, 'tokens_per_sec': 412.1153920000838, 'avg_layers_used': 12.08, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[12, 14, 16, 18, 20], threshold=0.8)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.386, 'avg_latency_sec': 0.1063947434425354, 'tokens_per_sec': 879.3479543520059, 'avg_layers_used': 12.42, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.9
# Exit Layers = [12, 14, 16, 18, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[12, 14, 16, 18, 20], threshold=0.9)...
# sst2 {'metric': 'accuracy', 'score': 0.518, 'avg_latency_sec': 0.05863542079925537, 'tokens_per_sec': 402.0436739203784, 'avg_layers_used': 12.268, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[12, 14, 16, 18, 20], threshold=0.9)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.356, 'avg_latency_sec': 0.10881366300582886, 'tokens_per_sec': 859.8001153126179, 'avg_layers_used': 12.7, 'num_samples': 500}
#
# ----------------------------
# Threshold = 1.0
# Exit Layers = [12, 14, 16, 18, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[12, 14, 16, 18, 20], threshold=1.0)...
# sst2 {'metric': 'accuracy', 'score': 0.724, 'avg_latency_sec': 0.12761048555374147, 'tokens_per_sec': 184.73403574718103, 'avg_layers_used': 24.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[12, 14, 16, 18, 20], threshold=1.0)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.18, 'avg_latency_sec': 0.21921812677383423, 'tokens_per_sec': 426.7804007673285, 'avg_layers_used': 24.0, 'num_samples': 500}
#
# =================================================
# Testing EXIT LAYERS: [6, 18, 24]
# =================================================
#
# ----------------------------
# Threshold = 0.5
# Exit Layers = [6, 18, 24]
# ----------------------------
#
# Testing sst2 (exit_layers=[6, 18, 24], threshold=0.5)...
# sst2 {'metric': 'accuracy', 'score': 0.55, 'avg_latency_sec': 0.030763113021850585, 'tokens_per_sec': 766.3073624329155, 'avg_layers_used': 6.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[6, 18, 24], threshold=0.5)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.47, 'avg_latency_sec': 0.05413951921463013, 'tokens_per_sec': 1728.090706330429, 'avg_layers_used': 6.0, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.6
# Exit Layers = [6, 18, 24]
# ----------------------------
#
# Testing sst2 (exit_layers=[6, 18, 24], threshold=0.6)...
# sst2 {'metric': 'accuracy', 'score': 0.546, 'avg_latency_sec': 0.03767946815490723, 'tokens_per_sec': 625.6457735306387, 'avg_layers_used': 7.416, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[6, 18, 24], threshold=0.6)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.474, 'avg_latency_sec': 0.05628653478622436, 'tokens_per_sec': 1662.1737393380538, 'avg_layers_used': 6.324, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.7
# Exit Layers = [6, 18, 24]
# ----------------------------
#
# Testing sst2 (exit_layers=[6, 18, 24], threshold=0.7)...
# sst2 {'metric': 'accuracy', 'score': 0.538, 'avg_latency_sec': 0.04591877460479736, 'tokens_per_sec': 513.3847800358571, 'avg_layers_used': 9.204, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[6, 18, 24], threshold=0.7)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.454, 'avg_latency_sec': 0.059751813411712644, 'tokens_per_sec': 1565.7767464788042, 'avg_layers_used': 6.972, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.8
# Exit Layers = [6, 18, 24]
# ----------------------------
#
# Testing sst2 (exit_layers=[6, 18, 24], threshold=0.8)...
# sst2 {'metric': 'accuracy', 'score': 0.548, 'avg_latency_sec': 0.0586231369972229, 'tokens_per_sec': 402.127917533938, 'avg_layers_used': 12.12, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[6, 18, 24], threshold=0.8)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.446, 'avg_latency_sec': 0.0624776029586792, 'tokens_per_sec': 1497.464620431684, 'avg_layers_used': 7.428, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.9
# Exit Layers = [6, 18, 24]
# ----------------------------
#
# Testing sst2 (exit_layers=[6, 18, 24], threshold=0.9)...
# sst2 {'metric': 'accuracy', 'score': 0.548, 'avg_latency_sec': 0.07633592224121094, 'tokens_per_sec': 308.8192204649002, 'avg_layers_used': 15.984, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[6, 18, 24], threshold=0.9)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.436, 'avg_latency_sec': 0.07014501571655274, 'tokens_per_sec': 1333.7797282426484, 'avg_layers_used': 8.58, 'num_samples': 500}
#
# ----------------------------
# Threshold = 1.0
# Exit Layers = [6, 18, 24]
# ----------------------------
#
# Testing sst2 (exit_layers=[6, 18, 24], threshold=1.0)...
# sst2 {'metric': 'accuracy', 'score': 0.724, 'avg_latency_sec': 0.12017054653167725, 'tokens_per_sec': 196.17119735563352, 'avg_layers_used': 24.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[6, 18, 24], threshold=1.0)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.18, 'avg_latency_sec': 0.21093798971176148, 'tokens_per_sec': 443.53319251711537, 'avg_layers_used': 24.0, 'num_samples': 500}
#
# =================================================
# Testing EXIT LAYERS: [4, 8, 12, 16, 20]
# =================================================
#
# ----------------------------
# Threshold = 0.5
# Exit Layers = [4, 8, 12, 16, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[4, 8, 12, 16, 20], threshold=0.5)...
# sst2 {'metric': 'accuracy', 'score': 0.492, 'avg_latency_sec': 0.022378241539001465, 'tokens_per_sec': 1053.4339777732102, 'avg_layers_used': 4.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[4, 8, 12, 16, 20], threshold=0.5)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.488, 'avg_latency_sec': 0.038104197025299075, 'tokens_per_sec': 2455.320077677603, 'avg_layers_used': 4.0, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.6
# Exit Layers = [4, 8, 12, 16, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[4, 8, 12, 16, 20], threshold=0.6)...
# sst2 {'metric': 'accuracy', 'score': 0.508, 'avg_latency_sec': 0.02291800022125244, 'tokens_per_sec': 1028.623779230931, 'avg_layers_used': 4.128, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[4, 8, 12, 16, 20], threshold=0.6)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.496, 'avg_latency_sec': 0.038640068531036374, 'tokens_per_sec': 2421.2689976171387, 'avg_layers_used': 4.128, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.7
# Exit Layers = [4, 8, 12, 16, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[4, 8, 12, 16, 20], threshold=0.7)...
# sst2 {'metric': 'accuracy', 'score': 0.512, 'avg_latency_sec': 0.023995479106903077, 'tokens_per_sec': 982.4350618287166, 'avg_layers_used': 4.288, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[4, 8, 12, 16, 20], threshold=0.7)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.496, 'avg_latency_sec': 0.03928955459594727, 'tokens_per_sec': 2381.2435890950655, 'avg_layers_used': 4.272, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.8
# Exit Layers = [4, 8, 12, 16, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[4, 8, 12, 16, 20], threshold=0.8)...
# sst2 {'metric': 'accuracy', 'score': 0.528, 'avg_latency_sec': 0.02667043447494507, 'tokens_per_sec': 883.9001112691305, 'avg_layers_used': 4.768, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[4, 8, 12, 16, 20], threshold=0.8)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.472, 'avg_latency_sec': 0.04195461225509643, 'tokens_per_sec': 2229.9812814653064, 'avg_layers_used': 4.768, 'num_samples': 500}
#
# ----------------------------
# Threshold = 0.9
# Exit Layers = [4, 8, 12, 16, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[4, 8, 12, 16, 20], threshold=0.9)...
# sst2 {'metric': 'accuracy', 'score': 0.55, 'avg_latency_sec': 0.03729617738723755, 'tokens_per_sec': 632.0755008009704, 'avg_layers_used': 6.64, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[4, 8, 12, 16, 20], threshold=0.9)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.45, 'avg_latency_sec': 0.046308629989624026, 'tokens_per_sec': 2020.3145724881676, 'avg_layers_used': 5.496, 'num_samples': 500}
#
# ----------------------------
# Threshold = 1.0
# Exit Layers = [4, 8, 12, 16, 20]
# ----------------------------
#
# Testing sst2 (exit_layers=[4, 8, 12, 16, 20], threshold=1.0)...
# sst2 {'metric': 'accuracy', 'score': 0.724, 'avg_latency_sec': 0.1286448621749878, 'tokens_per_sec': 183.2486708092059, 'avg_layers_used': 24.0, 'num_samples': 500}
#
# Testing amazon_polarity (exit_layers=[4, 8, 12, 16, 20], threshold=1.0)...
# amazon_polarity {'metric': 'accuracy', 'score': 0.18, 'avg_latency_sec': 0.220861647605896, 'tokens_per_sec': 423.60455522338697, 'avg_layers_used': 24.0, 'num_samples': 500}

# %%
import pandas as pd
df=pd.DataFrame(results_table)
df.to_csv("results.csv", index=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

df2 = df.copy()

# Replace NaN thresholds with 'baseline'
df2['threshold'] = df2['threshold'].apply(
    lambda x: "baseline" if pd.isna(x) else x
)

# Convert exit_layers list → string for grouping
df2['exit_layers_str'] = df2['exit_layers'].apply(lambda x: str(x))

datasets = df2['dataset'].unique()

for ds in datasets:

    df_ds = df2[df2['dataset'] == ds]

    # Get all exit_layers configs EXCEPT baseline
    exit_configs = sorted(df_ds['exit_layers_str'].unique())
    exit_configs = [cfg for cfg in exit_configs if cfg != "nan"]

    # Only keep configs that are real lists (not baseline)
    # ensure exactly 4 for plotting (or fewer → still works)
    # Corrected: ensure enough subplots for all exit_configs
    # If there are more than 4 exit_configs, this will still plot only up to 8 configurations.
    max_plots_per_dataset = min(len(exit_configs), 8)


    ncols = 2
    nrows = math.ceil(max_plots_per_dataset / ncols)

    fig, axes = plt.subplots(
        nrows,
        ncols,
        figsize=(14, 5 * nrows)
    )
    axes = np.array(axes).flatten()
    # ==========================

    # Extract baseline row(s)
    df_base = df_ds[df_ds['mode'] == "baseline"]

    # ---------- LOOP OVER EXIT CONFIGS ----------
    for idx, exit_cfg in enumerate(exit_configs[:max_plots_per_dataset]):  # Limit loop to actual number of plots

        ax = axes[idx]

        # Subset for this exit layers
        df_sub = df_ds[df_ds['exit_layers_str'] == exit_cfg]

        ###########################################
        # 1) Extract values (early-exit run)
        ###########################################
        # Early exit values
        thresholds = df_sub['threshold'].tolist()
        scores     = df_sub['score'].tolist()
        layers     = df_sub['avg_layers_used'].tolist()
        tps        = df_sub['tokens_per_sec'].tolist()

        # Add baseline explicitly (first element)
        if not df_base.empty:
            thresholds = ["baseline"] + thresholds
            scores     = [df_base['score'].iloc[0]] + scores
            layers     = [df_base['avg_layers_used'].iloc[0]] + layers
            tps        = [df_base['tokens_per_sec'].iloc[0]] + tps


        ###########################################
        # 2) Extract baseline values
        ###########################################
        base_thresholds = df_base['threshold'].tolist()
        base_scores     = df_base['score'].tolist()
        base_layers     = df_base['avg_layers_used'].tolist()
        base_tps        = df_base['tokens_per_sec'].tolist()

        # ---- Sorting helper: baseline always first ----
        def sort_key(x):
            return -1 if x == "baseline" else float(x)

        sorted_idx = sorted(
            range(len(thresholds)),
            key=lambda i: sort_key(thresholds[i])
        )

        thresholds = [thresholds[i] for i in sorted_idx]
        scores     = [scores[i]     for i in sorted_idx]
        layers     = [layers[i]     for i in sorted_idx]
        tps        = [tps[i]        for i in sorted_idx]

        x_pos = np.arange(len(thresholds))

        ################################################
        # ---- PLOTS (same style as your original) ----
        ################################################
        ax1 = ax

        # Accuracy curve
        ax1.plot(x_pos, scores, marker="o", color="tab:blue", label="Accuracy")
        ax1.set_ylabel("Accuracy", color="tab:blue")
        ax1.tick_params(axis="y", labelcolor="tab:blue")

        # Plot baseline point in gold
        for i, th in enumerate(thresholds):
            if th == "baseline":
                ax1.scatter(
                    x_pos[i], scores[i],
                    color="gold", s=140, edgecolor="black", zorder=6,
                    label="Baseline"
                )

        # Avg layers
        ax2 = ax1.twinx()
        ax2.plot(
            x_pos, layers,
            marker="s", linestyle="--",
            color="tab:red", label="Layers Used"
        )
        ax2.set_ylabel("Avg Layers Used", color="tab:red")
        ax2.tick_params(axis="y", labelcolor="tab:red")

        # Tokens/sec
        ax3 = ax1.twinx()
        ax3.spines["right"].set_position(("outward", 50))
        ax3.plot(
            x_pos, tps,
            marker="^", linestyle=":",
            color="tab:green", label="Tokens/sec"
        )
        ax3.set_ylabel("Tokens/sec", color="tab:green")
        ax3.tick_params(axis="y", labelcolor="tab:green")

        ax.set_xticks(x_pos)
        ax.set_xticklabels(thresholds)
        ax.set_title(f"exit_layers = {exit_cfg}")

        ax.grid(True, linestyle="--", alpha=0.3)

    for j in range(max_plots_per_dataset, len(axes)):
        fig.delaxes(axes[j])

    # ------- FIGURE TITLE -------
    fig.suptitle(f"GPT-2 Early-Exit Trade-Off Curves: {ds}", fontsize=16)
    plt.tight_layout()
    plt.show()
